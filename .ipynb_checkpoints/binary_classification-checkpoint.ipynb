# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
from torchsummary import summary
import torch.optim as optim

import pennylane as qml
from pennylane import numpy as np

from matplotlib import pyplot as plt
# %matplotlib inline

from utils.tools import get_dataset, visualise_data, train_and_plot_accuracy, test_loop
from utils.models import NetCNN, NeuralNetwork, QNN, PGD

# %%
device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
digits = [3, 5, 8, 9]
n_classes = len(digits)
n_px = 8

n_qubits = int(np.log2(n_px * n_px))
n_layers = 16

train_size = 1000
test_size = 200

batch_size = 32
epochs = 30
lr = 1e-3

# %%
# Load and prepare dataset
(x_train, y_train), (x_test, y_test) = get_dataset(digits=digits, n_px=n_px, train_size=train_size, test_size=test_size)
train_loader = DataLoader(TensorDataset(x_train, y_train), batch_size=batch_size, shuffle=True)
test_loader = DataLoader(TensorDataset(x_test,  y_test),  batch_size=batch_size)

# %%
# show one image from each class (in the train- and testsets, the images are randomly permuted)
x_vis = [(x_train[y_train == i])[0].squeeze(0) for i in range(len(digits))]
y_vis = digits

visualise_data(x_vis, y_vis)

# %%
model_CNN = NetCNN(n_px=n_px, n_classes=n_classes).to(device)
summary(model_CNN,input_size=(1,n_px,n_px))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1              [-1, 8, 8, 8]              80
#          MaxPool2d-2              [-1, 8, 4, 4]               0
#             Conv2d-3             [-1, 16, 4, 4]           1,168
#          MaxPool2d-4             [-1, 16, 2, 2]               0
#             Linear-5                   [-1, 16]           1,040
#             Linear-6                    [-1, 4]              68
# ================================================================
# Total params: 2,356
# Trainable params: 2,356
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.02
# ----------------------------------------------------------------

# %%
model_feed_forward = NeuralNetwork(n_px=n_px, n_classes=n_classes).to(device)
summary(model_feed_forward, input_size=(1,n_px,n_px))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Flatten-1                   [-1, 64]               0
#             Linear-2                   [-1, 32]           2,080
#               ReLU-3                   [-1, 32]               0
#             Linear-4                    [-1, 8]             264
#               ReLU-5                    [-1, 8]               0
#             Linear-6                    [-1, 4]              36
# ================================================================
# Total params: 2,380
# Trainable params: 2,380
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.01
# ----------------------------------------------------------------

# %%
model_qml = QNN(n_qubits=n_qubits, n_classes=n_classes, n_layers=n_layers).to(device)
summary(model_qml, input_size=(1,n_px * n_px))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#         TorchLayer-1                    [-1, 6]               0
#             Linear-2                    [-1, 4]              28
# ================================================================
# Total params: 28
# Trainable params: 28
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.00
# Params size (MB): 0.00
# Estimated Total Size (MB): 0.00
# ----------------------------------------------------------------

# %%
train_and_plot_accuracy(model_CNN, train_loader, test_loader, epochs=epochs, lr=lr, device=device)
# Out:
# Epoch 5/30 | Train Loss: 1.1243 | Train Acc: 52.80% | Test Loss: 1.0994 | Test Acc: 50.50% | Learning Rate: 0.001000
# Epoch 10/30 | Train Loss: 0.7466 | Train Acc: 74.30% | Test Loss: 0.8047 | Test Acc: 73.50% | Learning Rate: 0.001000
# Epoch 15/30 | Train Loss: 0.5284 | Train Acc: 81.50% | Test Loss: 0.5637 | Test Acc: 82.50% | Learning Rate: 0.001000
# Epoch 20/30 | Train Loss: 0.3834 | Train Acc: 87.60% | Test Loss: 0.4606 | Test Acc: 83.00% | Learning Rate: 0.001000
# Epoch 25/30 | Train Loss: 0.3067 | Train Acc: 90.00% | Test Loss: 0.3784 | Test Acc: 85.50% | Learning Rate: 0.001000
# Epoch 30/30 | Train Loss: 0.2586 | Train Acc: 92.20% | Test Loss: 0.3681 | Test Acc: 85.50% | Learning Rate: 0.001000
#
# Training completed in 5.33 seconds.

# %%
train_and_plot_accuracy(model_feed_forward, train_loader, test_loader, epochs=epochs, lr=lr, device=device)
# Out:
# Epoch 5/30 | Train Loss: 0.9223 | Train Acc: 63.30% | Test Loss: 0.9165 | Test Acc: 63.00% | Learning Rate: 0.001000
# Epoch 10/30 | Train Loss: 0.6424 | Train Acc: 73.30% | Test Loss: 0.6900 | Test Acc: 70.50% | Learning Rate: 0.001000
# Epoch 15/30 | Train Loss: 0.5375 | Train Acc: 81.20% | Test Loss: 0.5974 | Test Acc: 76.00% | Learning Rate: 0.001000
# Epoch 20/30 | Train Loss: 0.4501 | Train Acc: 86.10% | Test Loss: 0.5297 | Test Acc: 83.00% | Learning Rate: 0.001000
# Epoch 25/30 | Train Loss: 0.3881 | Train Acc: 87.40% | Test Loss: 0.4906 | Test Acc: 85.00% | Learning Rate: 0.001000
# Epoch 30/30 | Train Loss: 0.3452 | Train Acc: 88.80% | Test Loss: 0.4707 | Test Acc: 85.00% | Learning Rate: 0.001000
#
# Training completed in 3.70 seconds.

# %%
model_qml = QNN(n_qubits=n_qubits, n_classes=n_classes, n_layers=n_layers).to("cpu")
train_and_plot_accuracy(model_qml, train_loader, test_loader, epochs=epochs, lr=lr, device="cpu")
# Out:
# Epoch 5/30 | Train Loss: 1.2015 | Train Acc: 55.10% | Test Loss: 1.2123 | Test Acc: 51.50% | Learning Rate: 0.001000
# Epoch 10/30 | Train Loss: 1.0461 | Train Acc: 62.90% | Test Loss: 1.0780 | Test Acc: 61.50% | Learning Rate: 0.001000
# Epoch 15/30 | Train Loss: 0.9498 | Train Acc: 71.00% | Test Loss: 0.9938 | Test Acc: 68.00% | Learning Rate: 0.001000
# Epoch 20/30 | Train Loss: 0.8754 | Train Acc: 75.70% | Test Loss: 0.9218 | Test Acc: 76.50% | Learning Rate: 0.001000
# Epoch 25/30 | Train Loss: 0.8109 | Train Acc: 78.80% | Test Loss: 0.8589 | Test Acc: 78.50% | Learning Rate: 0.001000
# Epoch 30/30 | Train Loss: 0.7554 | Train Acc: 81.20% | Test Loss: 0.8036 | Test Acc: 78.50% | Learning Rate: 0.001000
#
# Training completed in 180.59 seconds.

# %% [markdown]
# ## Adversarial attacks

# %%
def PGD(model, feats, labels, epsilon=0.1, alpha=None, num_iter=10):
    if alpha is None:
        alpha = epsilon/num_iter
    
    model.eval()  # Ensure model is in eval mode
    feats = feats.clone().detach().to(device)
    labels = labels.clone().detach().to(device)
    
    # Start with zero perturbation
    delta = torch.zeros_like(feats, requires_grad=True).to(device)
    
    for t in range(num_iter):
        outputs = model(feats + delta)
        loss = nn.CrossEntropyLoss()(outputs, labels)
        loss.backward()
        
        # Update delta and clamp it to epsilon
        delta.data = (delta + alpha * delta.grad.detach().sign()).clamp(-epsilon, epsilon)
        delta.grad.zero_()
    
    return delta.detach()

# %%
x_perturb = x_test.to(device)
y_perturb = y_test.to(device)
perturbations = PGD(model=model_CNN, feats=x_perturb, labels=y_perturb, epsilon=0.18, alpha=0.01, num_iter=100)

# %%
# show one image from each class (in the train- and testsets, the images are randomly permuted)
x_vis = [(x_perturb[y_perturb == i])[0].squeeze(0).to("cpu") for i in range(len(digits))]
y_vis = digits

visualise_data(x_vis, y_vis)

# %%
x_perturb = x_perturb + perturbations

# show one image from each class (in the train- and testsets, the images are randomly permuted)
x_vis = [(x_perturb[y_perturb == i])[0].squeeze(0).to("cpu") for i in range(len(digits))]
y_vis = digits

visualise_data(x_vis, y_vis)

# %%
loss_fn = nn.CrossEntropyLoss()

# Evaluate model on adversarial examples
def evaluate_under_attack(model, base_feats, labels, epsilons, alpha, num_iter):
    acc_list = []

    for eps in epsilons:
        perturb = PGD(model, base_feats, labels, epsilon=eps, alpha=alpha, num_iter=num_iter)
        x_adv = (base_feats + perturb).clamp(0, 1)  # Clamp to valid pixel range
        adv_loader = DataLoader(TensorDataset(x_adv, labels), batch_size=batch_size)
        _, acc = test_loop(adv_loader, model, loss_fn, device)
        acc_list.append(acc)

    return acc_list

# Settings
epsilons = np.linspace(0, 0.2, 10).numpy()  # Change range/resolution as needed
x_perturb = x_test.to(device)
y_perturb = y_test.to(device)
alpha = 1e-2
num_iter = 100
model_qml.to(device)
# Evaluate both models
accs_cnn = evaluate_under_attack(model_CNN, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_neural = evaluate_under_attack(model_feed_forward, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_qml = evaluate_under_attack(model_qml, x_perturb, y_perturb, epsilons, alpha, num_iter)

# %%
# Plot
plt.figure(figsize=(8, 5))
plt.plot(epsilons, accs_cnn, 'bs-', label='CNN Model')
plt.plot(epsilons, accs_neural, 'ro-', label='Neural Model')
plt.plot(epsilons, accs_qml, 'g^-', label='QNN Model')
plt.xlabel('Epsilon (ε)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epsilon under PGD Attack')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Quantum to classical transfer attack

# %%
# Evaluate model on adversarial examples
def evaluate_under_attack(model, base_feats, labels, epsilons, alpha, num_iter):
    acc_list = []

    for eps in epsilons:
        perturb = PGD(model_qml, base_feats, labels, epsilon=eps, alpha=alpha, num_iter=num_iter)
        x_adv = (base_feats + perturb).clamp(0, 1)  # Clamp to valid pixel range
        adv_loader = DataLoader(TensorDataset(x_adv, labels), batch_size=batch_size)
        _, acc = test_loop(adv_loader, model, loss_fn, device)
        acc_list.append(acc)

    return acc_list

# Settings
epsilons = np.linspace(0, 0.2, 10).numpy()  # Change range/resolution as needed
x_perturb = x_test.to(device)
y_perturb = y_test.to(device)
alpha = 1e-2
num_iter = 10
model_qml.to(device)
# Evaluate both models
accs_cnn = evaluate_under_attack(model_CNN, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_neural = evaluate_under_attack(model_feed_forward, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_qml = evaluate_under_attack(model_qml, x_perturb, y_perturb, epsilons, alpha, num_iter)

# %%
# Plot
plt.figure(figsize=(8, 5))
plt.plot(epsilons, accs_cnn, 'bs-', label='CNN Model')
plt.plot(epsilons, accs_neural, 'ro-', label='Neural Model')
plt.plot(epsilons, accs_qml, 'g^-', label='QNN Model')
plt.xlabel('Epsilon (ε)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epsilon under transfer attack (quantum to classical)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Evaluate model on adversarial examples
def evaluate_under_attack(model, base_feats, labels, epsilons, alpha, num_iter):
    acc_list = []

    for eps in epsilons:
        perturb = PGD(model_CNN, base_feats, labels, epsilon=eps, alpha=alpha, num_iter=num_iter)
        x_adv = (base_feats + perturb).clamp(0, 1)  # Clamp to valid pixel range
        adv_loader = DataLoader(TensorDataset(x_adv, labels), batch_size=batch_size)
        _, acc = test_loop(adv_loader, model, loss_fn, device)
        acc_list.append(acc)

    return acc_list

# Settings
epsilons = np.linspace(0, 0.2, 10).numpy()  # Change range/resolution as needed
x_perturb = x_test.to(device)
y_perturb = y_test.to(device)
alpha = 1e-2
num_iter = 100
model_qml.to(device)
# Evaluate both models
accs_cnn = evaluate_under_attack(model_CNN, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_neural = evaluate_under_attack(model_feed_forward, x_perturb, y_perturb, epsilons, alpha, num_iter)
accs_qml = evaluate_under_attack(model_qml, x_perturb, y_perturb, epsilons, alpha, num_iter)

# %%
# Plot
plt.figure(figsize=(8, 5))
plt.plot(epsilons, accs_cnn, 'bs-', label='CNN Model')
plt.plot(epsilons, accs_neural, 'ro-', label='Neural Model')
plt.plot(epsilons, accs_qml, 'g^-', label='QNN Model')
plt.xlabel('Epsilon (ε)')
plt.ylabel('Accuracy')
plt.title('Accuracy vs. Epsilon under transfer attack (classical to quantum)')
plt.legend()
plt.grid(True)
plt.show()

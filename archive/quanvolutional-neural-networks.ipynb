# %% [markdown]
# # Quanvolutional Neural Networks
# Based on the PennyLane [demo](https://pennylane.ai/qml/demos/tutorial_quanvolution). Refer to this [paper](https://arxiv.org/abs/1904.04767).

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.templates import RandomLayers
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# Out:
# 2025-03-17 10:44:43.684305: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742168683.700452  194586 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742168683.705440  194586 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1742168683.718138  194586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742168683.718155  194586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742168683.718157  194586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1742168683.718159  194586 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-03-17 10:44:43.722434: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Model hyper-parameters

# %%
n_epochs = 30   # Number of optimization epochs
n_layers = 1    # Number of random layers
n_train = 50    # Size of the train dataset
n_test = 30     # Size of the test dataset

SAVE_PATH = "../adversarial-qml/demonstration_assets/quanvolution/"  # Data saving folder
PREPROCESS = True           # If False, skip quantum processing and load data from SAVE_PATH
np.random.seed(0)           # Seed for NumPy random number generator
tf.random.set_seed(0)       # Seed for TensorFlow random number generator

# %% [markdown]
# MNIST dataset is loaded from _Keras_.

# %%
mnist_dataset = keras.datasets.mnist
(train_images, train_labels), (test_images, test_labels) = mnist_dataset.load_data()

# Reduce dataset size (increase the size in hyper-parameters for better performance)
train_images = train_images[:n_train]
train_labels = train_labels[:n_train]
test_images = test_images[:n_test]
test_labels = test_labels[:n_test]

# Normalize pixel values within 0 and 1
train_images = train_images / 255
test_images = test_images / 255

# Add extra dimension for convolution channels
train_images = np.array(train_images[..., tf.newaxis], requires_grad=False)
test_images = np.array(test_images[..., tf.newaxis], requires_grad=False)

# %% [markdown]
# ## Quanvolutional kernel: a quantum circuit as a convolutional kernel

# %%
dev = qml.device("default.qubit", wires=4)
# Random circuit parameters
rand_params = np.random.uniform(high=2 * np.pi, size=(n_layers, 4))

@qml.qnode(dev)
def circuit(phi):
    # Encoding of 4 classical input values
    for j in range(4):
        qml.RY(np.pi * phi[j], wires=j)

    # Random quantum circuit
    RandomLayers(rand_params, wires=list(range(4)))

    # Measurement producing 4 classical output values
    return [qml.expval(qml.PauliZ(j)) for j in range(4)]

# %%
def quanv(image):
    """Convolves the input image with many applications of the same quantum circuit."""
    out = np.zeros((14, 14, 4))

    # Loop over the coordinates of the top-left pixel of 2X2 squares
    for j in range(0, 28, 2):
        for k in range(0, 28, 2):
            # Process a squared 2x2 region of the image with a quantum circuit
            q_results = circuit(
                [
                    image[j, k, 0],
                    image[j, k + 1, 0],
                    image[j + 1, k, 0],
                    image[j + 1, k + 1, 0]
                ]
            )
            # Assign expectation values to different channels of the output pixel (j/2, k/2)
            for c in range(4):
                out[j // 2, k // 2, c] = q_results[c]
    return out

# %% [markdown]
# The quantum kernel is not trainable (here) and can be thought of as a _pre-processing_ step.

# %%
if PREPROCESS == True:
    q_train_images = []
    print("Quantum pre-processing of train images:")
    for idx, img in enumerate(train_images):
        print("{}/{}        ".format(idx + 1, n_train), end="\r")
        q_train_images.append(quanv(img))
    q_train_images = np.asarray(q_train_images)

    q_test_images = []
    print("\nQuantum pre-processing of test images:")
    for idx, img in enumerate(test_images):
        print("{}/{}        ".format(idx + 1, n_test), end="\r")
        q_test_images.append(quanv(img))
    q_test_images = np.asarray(q_test_images)

    # Save pre-processed images
    np.save(SAVE_PATH + "q_train_images.npy", q_train_images)
    np.save(SAVE_PATH + "q_test_images.npy", q_test_images)


# Load pre-processed images
q_train_images = np.load(SAVE_PATH + "q_train_images.npy")
q_test_images = np.load(SAVE_PATH + "q_test_images.npy")
# Out:
# Quantum pre-processing of train images:
# 50/50
# Quantum pre-processing of test images:
# 30/30

# %%
n_samples = 4
n_channels = 4
fig, axes = plt.subplots(1 + n_channels, n_samples, figsize=(10, 10))
for k in range(n_samples):
    axes[0, 0].set_ylabel("Input")
    if k != 0:
        axes[0, k].yaxis.set_visible(False)
    axes[0, k].imshow(train_images[k, :, :, 0], cmap="gray")

    # Plot all output channels
    for c in range(n_channels):
        axes[c + 1, 0].set_ylabel("Output [ch. {}]".format(c))
        if k != 0:
            axes[c, k].yaxis.set_visible(False)
        axes[c + 1, k].imshow(q_train_images[k, :, :, c], cmap="gray")

plt.tight_layout()
plt.show()

# %% [markdown]
# Notice that the images are downscaled (lower resolution). Different channels have different distortions introduced by the quantum kernel, but the overall structure is the same.

# %% [markdown]
# ## Classification using a hybrid quantum-classical model

# %%
def MyModel():
    """Initializes and returns a custom Keras model
    which is ready to be trained."""
    model = keras.models.Sequential([
        keras.layers.Flatten(),
        keras.layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer='adam', # stochastic-gradient-descent
        loss="sparse_categorical_crossentropy", # cross-entropy
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ### Training

# %%
q_model = MyModel()

q_history = q_model.fit(
    q_train_images,
    train_labels,
    validation_data=(q_test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 2s - 122ms/step - accuracy: 0.1400 - loss: 2.6896 - val_accuracy: 0.1667 - val_loss: 2.2419
# Epoch 2/30
# 13/13 - 0s - 7ms/step - accuracy: 0.3000 - loss: 1.9317 - val_accuracy: 0.1667 - val_loss: 2.0872
# Epoch 3/30
# 13/13 - 0s - 6ms/step - accuracy: 0.5800 - loss: 1.6237 - val_accuracy: 0.3333 - val_loss: 1.8933
# Epoch 4/30
# 13/13 - 0s - 6ms/step - accuracy: 0.7800 - loss: 1.3131 - val_accuracy: 0.4000 - val_loss: 1.7403
# Epoch 5/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9000 - loss: 1.0825 - val_accuracy: 0.5333 - val_loss: 1.6349
# Epoch 6/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.8992 - val_accuracy: 0.5667 - val_loss: 1.5442
# Epoch 7/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9400 - loss: 0.7544 - val_accuracy: 0.6333 - val_loss: 1.4681
# Epoch 8/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9600 - loss: 0.6411 - val_accuracy: 0.6667 - val_loss: 1.4085
# Epoch 9/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9600 - loss: 0.5491 - val_accuracy: 0.6667 - val_loss: 1.3590
# Epoch 10/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9600 - loss: 0.4748 - val_accuracy: 0.7000 - val_loss: 1.3174
# Epoch 11/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9800 - loss: 0.4141 - val_accuracy: 0.7000 - val_loss: 1.2825
# Epoch 12/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9800 - loss: 0.3637 - val_accuracy: 0.7000 - val_loss: 1.2531
# Epoch 13/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9800 - loss: 0.3218 - val_accuracy: 0.7000 - val_loss: 1.2280
# Epoch 14/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2865 - val_accuracy: 0.7000 - val_loss: 1.2064
# Epoch 15/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.2567 - val_accuracy: 0.7000 - val_loss: 1.1878
# Epoch 16/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2313 - val_accuracy: 0.7000 - val_loss: 1.1715
# Epoch 17/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2095 - val_accuracy: 0.7000 - val_loss: 1.1572
# Epoch 18/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1907 - val_accuracy: 0.7000 - val_loss: 1.1446
# Epoch 19/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1744 - val_accuracy: 0.7000 - val_loss: 1.1333
# Epoch 20/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1602 - val_accuracy: 0.7000 - val_loss: 1.1232
# Epoch 21/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1477 - val_accuracy: 0.7333 - val_loss: 1.1141
# Epoch 22/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1367 - val_accuracy: 0.7333 - val_loss: 1.1059
# Epoch 23/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1269 - val_accuracy: 0.7333 - val_loss: 1.0984
# Epoch 24/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1182 - val_accuracy: 0.7333 - val_loss: 1.0915
# Epoch 25/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1104 - val_accuracy: 0.7333 - val_loss: 1.0853
# Epoch 26/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1035 - val_accuracy: 0.7333 - val_loss: 1.0795
# Epoch 27/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0971 - val_accuracy: 0.7333 - val_loss: 1.0741
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0914 - val_accuracy: 0.7333 - val_loss: 1.0692
# Epoch 29/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.0862 - val_accuracy: 0.7333 - val_loss: 1.0646
# Epoch 30/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.0815 - val_accuracy: 0.7333 - val_loss: 1.0603

# %% [markdown]
# ### Classical model for comparison

# %%
# c_model = MyModel()
c_model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_4 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 10)             │         7,850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,552 (92.00 KB)
#  Trainable params: 7,850 (30.66 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 15,702 (61.34 KB)

# %%
c_model = MyModel()

c_history = c_model.fit(
    train_images,
    train_labels,
    validation_data=(test_images, test_labels),
    batch_size=4,
    epochs=n_epochs,
    verbose=2,
)
# Out:
# Epoch 1/30
# 13/13 - 2s - 135ms/step - accuracy: 0.1000 - loss: 2.3156 - val_accuracy: 0.3000 - val_loss: 2.1497
# Epoch 2/30
# 13/13 - 0s - 8ms/step - accuracy: 0.5600 - loss: 1.9018 - val_accuracy: 0.3333 - val_loss: 2.0006
# Epoch 3/30
# 13/13 - 0s - 7ms/step - accuracy: 0.6800 - loss: 1.6158 - val_accuracy: 0.3667 - val_loss: 1.8719
# Epoch 4/30
# 13/13 - 0s - 7ms/step - accuracy: 0.7600 - loss: 1.3845 - val_accuracy: 0.4000 - val_loss: 1.7577
# Epoch 5/30
# 13/13 - 0s - 7ms/step - accuracy: 0.8400 - loss: 1.1925 - val_accuracy: 0.4667 - val_loss: 1.6586
# Epoch 6/30
# 13/13 - 0s - 7ms/step - accuracy: 0.8800 - loss: 1.0331 - val_accuracy: 0.5000 - val_loss: 1.5748
# Epoch 7/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.9008 - val_accuracy: 0.5000 - val_loss: 1.5046
# Epoch 8/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9600 - loss: 0.7905 - val_accuracy: 0.5333 - val_loss: 1.4455
# Epoch 9/30
# 13/13 - 0s - 6ms/step - accuracy: 0.9800 - loss: 0.6980 - val_accuracy: 0.5667 - val_loss: 1.3954
# Epoch 10/30
# 13/13 - 0s - 7ms/step - accuracy: 0.9800 - loss: 0.6198 - val_accuracy: 0.6000 - val_loss: 1.3527
# Epoch 11/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.5534 - val_accuracy: 0.6000 - val_loss: 1.3161
# Epoch 12/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.4966 - val_accuracy: 0.6000 - val_loss: 1.2845
# Epoch 13/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.4477 - val_accuracy: 0.6000 - val_loss: 1.2571
# Epoch 14/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.4055 - val_accuracy: 0.6333 - val_loss: 1.2332
# Epoch 15/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.3688 - val_accuracy: 0.6667 - val_loss: 1.2123
# Epoch 16/30
# 13/13 - 0s - 8ms/step - accuracy: 1.0000 - loss: 0.3367 - val_accuracy: 0.6667 - val_loss: 1.1939
# Epoch 17/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.3086 - val_accuracy: 0.6667 - val_loss: 1.1777
# Epoch 18/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2838 - val_accuracy: 0.6667 - val_loss: 1.1633
# Epoch 19/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2619 - val_accuracy: 0.6667 - val_loss: 1.1504
# Epoch 20/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2424 - val_accuracy: 0.7000 - val_loss: 1.1389
# Epoch 21/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.2250 - val_accuracy: 0.7333 - val_loss: 1.1286
# Epoch 22/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.2094 - val_accuracy: 0.7333 - val_loss: 1.1193
# Epoch 23/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1955 - val_accuracy: 0.7333 - val_loss: 1.1109
# Epoch 24/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1829 - val_accuracy: 0.7333 - val_loss: 1.1033
# Epoch 25/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1715 - val_accuracy: 0.7333 - val_loss: 1.0963
# Epoch 26/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1611 - val_accuracy: 0.7333 - val_loss: 1.0900
# Epoch 27/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1517 - val_accuracy: 0.7333 - val_loss: 1.0842
# Epoch 28/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1431 - val_accuracy: 0.7333 - val_loss: 1.0790
# Epoch 29/30
# 13/13 - 0s - 6ms/step - accuracy: 1.0000 - loss: 0.1353 - val_accuracy: 0.7333 - val_loss: 1.0741
# Epoch 30/30
# 13/13 - 0s - 7ms/step - accuracy: 1.0000 - loss: 0.1281 - val_accuracy: 0.7333 - val_loss: 1.0697

# %% [markdown]
# ## Results

# %%
import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(6, 9))

ax1.plot(q_history.history["val_accuracy"], "-ob", label="With quantum layer")
ax1.plot(c_history.history["val_accuracy"], "-og", label="Without quantum layer")
ax1.set_ylabel("Accuracy")
ax1.set_ylim([0, 1])
ax1.set_xlabel("Epoch")
ax1.legend()

ax2.plot(q_history.history["val_loss"], "-ob", label="With quantum layer")
ax2.plot(c_history.history["val_loss"], "-og", label="Without quantum layer")
ax2.set_ylabel("Loss")
ax2.set_ylim(top=2.5)
ax2.set_xlabel("Epoch")
ax2.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Next Steps:
# * Implement this model on [downscaled MNIST](https://pennylane.ai/datasets/downscaled-mnist).
# * Make the quantum kernel trainable.
# * Explore variational circuits instead of random circuit.
